# %% [markdown]
# <a href="https://colab.research.google.com/github/furkansaygili6/Student-Grades-Prediction-with-Keras-/blob/main/Student_Grades_Prediction_with_Keras_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Student_Grades.csv")

# %%
df.head(3)
# Out:
#    Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0    2.5       0.5       0.0        2        2.3      21     C
# 1    5.1       1.5       0.5        4        4.9      47     B
# 2    3.2       1.0       0.5        3        2.9      27     C

# %%
y=df["Scores"]
x=df.drop(columns=["Scores","Grade"])
y=y.values.astype("float32")
x=x.values.astype("float32")

# %%
model=Sequential()
model.add(Dense(16))
model.add(Dense (32, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(1))

# %%
model.compile(optimizer="adam", loss="mse",)

# %%
model.fit(x,y, epochs=100,batch_size=16)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 2921.2544
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3086.1216
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3016.7405
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2999.4958
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3020.8032
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2903.6768
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3049.9900
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2615.8850
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3058.6960
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2908.0471
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2819.3064
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2680.9900
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2548.0757
# Epoch 14/100
# ...

# %%
df.head(3)
# Out:
#    Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 0    2.5       0.5       0.0        2        2.3      21     C
# 1    5.1       1.5       0.5        4        4.9      47     B
# 2    3.2       1.0       0.5        3        2.9      27     C

# %%
model.predict(np.array([[13,1,1,2,3.3]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# array([[45.723034]], dtype=float32)
